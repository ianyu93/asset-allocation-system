# %%
# import needed modules
import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px

# get adjusted closing prices of 5 selected companies with Quandl
data = pd.read_csv("prediction/SPX_prediction.csv", index_col=0).index.to_datetime

# reorganise data pulled by setting date as index with
# columns of tickers and their corresponding adjusted prices
clean = data.set_index('date')
table = clean.pivot(columns='ticker')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-3e7b59982fdd> in <module>
#      13 # reorganise data pulled by setting date as index with
#      14 # columns of tickers and their corresponding adjusted prices
# ---> 15 clean = data.set_index('date')
#      16 table = clean.pivot(columns='ticker')
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4553
#    4554         if missing:
# -> 4555             raise KeyError(f"None of {missing} are in the columns")
#    4556
#    4557         if inplace:
#
# KeyError: "None of ['date'] are in the columns"

# %%
pd.read_csv("prediction/SPX_prediction.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4361506f9e58> in <module>
# ----> 1 pd.read_csv("prediction/SPX_prediction.csv")
#
# NameError: name 'pd' is not defined

# %%
table
# Out:
#             adj_close
# ticker            CNP          F         GE    TSLA        WMT
# date
# 2014-01-02  19.116238  12.726742  24.266002  150.10  71.343743
# 2014-01-03  19.107861  12.784441  24.248354  149.56  71.108673
# 2014-01-06  19.132992  12.842140  24.054226  147.00  70.710863
# 2014-01-07  19.334039  12.677286  24.080698  149.36  70.927850
# 2014-01-08  19.132992  12.809169  24.010106  151.28  70.367299
# ...               ...        ...        ...     ...        ...
# 2016-12-23  23.895555  11.800021  31.055560  213.34  68.153672
# 2016-12-27  23.828189  11.733729  31.075043  219.53  68.310482
# 2016-12-28  23.520232  11.601144  30.880215  219.74  67.928257
# 2016-12-29  23.799318  11.582204  30.889956  214.68  67.879254
# 2016-12-30  23.712705  11.487500  30.782801  213.69  67.742045
#
# [756 rows x 5 columns]

# %%
# calculate daily and annual returns of the stocks
returns_daily = table.pct_change()
returns_annual = returns_daily.mean() * 250

# get daily and covariance of returns of the stock
cov_daily = returns_daily.cov()
cov_annual = cov_daily * 250

# %%
cov_daily
# Out:
#                  adj_close
# ticker                 CNP         F        GE      TSLA       WMT
#           ticker
# adj_close CNP     0.000164  0.000056  0.000061  0.000070  0.000042
#           F       0.000056  0.000211  0.000086  0.000117  0.000046
#           GE      0.000061  0.000086  0.000134  0.000089  0.000043
#           TSLA    0.000070  0.000117  0.000089  0.000707  0.000051
#           WMT     0.000042  0.000046  0.000043  0.000051  0.000129

# %%
# empty lists to store returns, volatility and weights of imiginary portfolios
port_returns = []
port_volatility = []
sharpe_ratio = []
stock_weights = []

# set the number of combinations for imaginary portfolios
num_assets = len(selected)
num_portfolios = 10000

#set random seed for reproduction's sake
np.random.seed(101)

# populate the empty lists with each portfolios returns,risk and weights
for single_portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights /= np.sum(weights)
    returns = np.dot(weights, returns_annual)
    volatility = np.sqrt(np.dot(weights.T, np.dot(cov_annual, weights)))
    sharpe = returns / volatility
    sharpe_ratio.append(sharpe)
    port_returns.append(returns)
    port_volatility.append(volatility)
    stock_weights.append(weights)

# a dictionary for Returns and Risk values of each portfolio
portfolio = {'Returns': port_returns,
             'Volatility': port_volatility,
             'Sharpe Ratio': sharpe_ratio}

# %%
# extend original dictionary to accomodate each ticker and weight in the portfolio
for counter,symbol in enumerate(selected):
    portfolio[symbol+' Weight'] = [Weight[counter] for Weight in stock_weights]

# make a nice dataframe of the extended dictionary
df = pd.DataFrame(portfolio)

# %%
# get better labels for desired arrangement of columns
column_order = ['Returns', 'Volatility', 'Sharpe Ratio'] + [stock+' Weight' for stock in selected]

# reorder dataframe columns
df = df[column_order]

# %%
# plot frontier, max sharpe & min Volatility values with a scatterplot
plt.style.use('seaborn-dark')
df.plot.scatter(x='Volatility', y='Returns', c='Sharpe Ratio',
                cmap='RdYlGn', edgecolors='black', figsize=(10, 8), grid=True)
plt.xlabel('Volatility (Std. Deviation)')
plt.ylabel('Expected Returns')
plt.title('Efficient Frontier')
plt.show()

# %%
# find min Volatility & max sharpe values in the dataframe (df)
min_volatility = df['Volatility'].min()
max_sharpe = df['Sharpe Ratio'].max()

# use the min, max values to locate and create the two special portfolios
sharpe_portfolio = df.loc[df['Sharpe Ratio'] == max_sharpe]
min_variance_port = df.loc[df['Volatility'] == min_volatility]

# %%
# plot frontier, max sharpe & min Volatility values with a scatterplot
plt.style.use('seaborn-dark')
df.plot.scatter(x='Volatility', y='Returns', c='Sharpe Ratio',
                cmap='RdYlGn', edgecolors='black', figsize=(10, 8), grid=True)
plt.scatter(x=sharpe_portfolio['Volatility'], y=sharpe_portfolio['Returns'], c='red', marker='D', s=200)
plt.scatter(x=min_variance_port['Volatility'], y=min_variance_port['Returns'], c='blue', marker='D', s=200 )
plt.xlabel('Volatility (Std. Deviation)')
plt.ylabel('Expected Returns')
plt.title('Efficient Frontier')
plt.show()

# %%
df
# Out:
#        Returns  Volatility  Sharpe Ratio  CNP Weight  F Weight  WMT Weight  \
# 0     0.040788    0.149496      0.272835    0.261820  0.289335    0.014437
# 1     0.104291    0.176221      0.591821    0.283065  0.104199    0.303335
# 2     0.079494    0.176328      0.450830    0.195196  0.124019    0.064062
# 3     0.118147    0.206389      0.572448    0.120722  0.043415    0.313581
# 4     0.058253    0.159980      0.364128    0.434703  0.328493    0.030755
# ...        ...         ...           ...         ...       ...         ...
# 9995  0.111435    0.255993      0.435305    0.023570  0.346427    0.108289
# 9996  0.066771    0.167159      0.399449    0.189457  0.208111    0.053145
# 9997  0.087172    0.170867      0.510174    0.182333  0.130783    0.219036
# 9998  0.087636    0.170051      0.515350    0.313484  0.234643    0.230132
# 9999  0.093871    0.181220      0.517994    0.192145  0.132238    0.190017
#
#       GE Weight  TSLA Weight
# 0      0.086964     0.347444
# 1      0.244927     0.064474
# 2      0.276685     0.340038
# 3      0.378758     0.143523
# 4      0.087453     0.118597
# ...         ...          ...
# 9995   0.495493     0.026221
# 9996   0.225189     0.324099
# 9997   0.247457     0.220392
# 9998   0.188619     0.033123
# 9999   0.289210     0.196390
#
# [10000 rows x 8 columns]

# %%
sharpe_portfolio
# Out:
#        Returns  Volatility  Sharpe Ratio  CNP Weight  F Weight  WMT Weight  \
# 2627  0.117454    0.178083      0.659549     0.37145  0.011162    0.375958
#
#       GE Weight  TSLA Weight
# 2627   0.232135     0.009294

# %%
fig = px.scatter(
    df, 
    x="Volatility", 
    y="Returns",  
    size_max=60,
    color="Sharpe Ratio",
    color_continuous_scale = 'aggrnyl',
    
)
fig.add_scatter(
    x=sharpe_portfolio['Volatility'], 
    y=sharpe_portfolio['Returns'],
    mode="markers",
    marker={'size': 20,'color': "red",},
    showlegend=False
)
fig.update_traces(textposition='top center')

fig.update_layout(
    height=800,
    title_text='Portfolio'
)

fig.show()
# Out:
# <div>                            <div id="4bde4078-9263-444c-b5c5-42137f1b7ca5" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4bde4078-9263-444c-b5c5-42137f1b7ca5")) {                    Plotly.newPlot(                        "4bde4078-9263-444c-b5c5-42137f1b7ca5",                        [{"hovertemplate": "Volatility=%{x}<br>Returns=%{y}<br>Sharpe Ratio=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [0.2728350583257238, 0.5918212623340268, 0.4508304716135933, 0.572448247519639, 0.3641277645515477, 0.5195500826364379, 0.37026079299603604, 0.3891281162810508, 0.5660063891745444, 0.40686620270483115, 0.3483265853535126, 0.19163515514543086, 0.430588676294825, 0.30486202625181685, 0.44577528883901235, 0.47327449437386504, 0.4272500074806733, 0.19544222041271536, 0.4371264599500305, 0.5179980490803904, 0.39087431889400026, 0.5091143694849093, 0.37601311697093115, 0.5793627096283497, 0.408998214579027, 0.4870299745108142, 0.5164896416785707, 0.48523093988392507, 0.5614370019561526, 0.31742981068083037, 0.4081559765243003, 0.30643272582970854, 0.32896395567384185, 0.3502542741376377, 0.4544778112845678, 0.45600361932867833, 0.4488676364269984, 0.4799215875203371, 0.43130422527755113, 0.4365914117066665, 0.34785911397633323, 0.456593365196737, 0.48770641444864066, 0.4397284468362539, 0.26353134979577764, 0.5440172154211315, 0.5045843912961274, 0.40203321216612925, 0.45618399240291035, 0.5404159021049731, 0.4169955333222763, 0.37302794147652585, 0.43334755721607515, 0.3264516466062428, 0.4544483697102709, 0.5692912333876479, 0.48293338136074176, 0.3340127370573039, 0.4602081501040793, 0.5021621942921775, 0.5103996092403522, 0.41906018363681996, 0.45566332384581504, 0.45777673216500353, 0.5334123730170772, 0.5100044936303302, 0.19942786200908913, 0.4768337860963536, 0.5215654521690428, 0.42664304683126125, 0.45035771070083547, 0.5692519992206361, 0.38559737860675586, 0.42723476993978404, 0.39207321948228135, 0.5131042025747657, 0.5742534458378725, 0.3018741508286946, 0.2793538943625143, 0.4906900257809157, 0.45654481822121906, 0.3076675285348642, 0.3757356151248483, 0.5947850506345763, 0.564099472205832, 0.5236256387896985, 0.5175328759619618, 0.5225449495493665, 0.31713071075557625, 0.43532800348836026, 0.49637667510327055, 0.3858753395404029, 0.5596976032419683, 0.6114759463122444, 0.547427235357147, 0.549169213965575, 0.4961636293204714, 0.6070537042455002, 0.488222897790502, 0.37678318676944206, 0.4915924771092746, 0.4755105044281363, 0.4080803051619497, 0.44545798948539245, 0.4664729077792612, 0.4758016611803767, 0.5129521103654399, 0.48899663171846075, 0.5466409796116339, 0.31800213803295563, 0.5785511781007684, 0.3924918416556888, 0.40240897903355977, 0.45396620239865987, 0.47561366672640326, 0.43592077795323647, 0.26589655042079374, 0.49077562063124874, 0.4264062572191802, 0.5107765159962694, 0.48676175435268054, 0.4523198695161471, 0.5591099179051467, 0.507379958312846, 0.5119114344566803, 0.564196015919769, 0.5611371774151882, 0.5681707854839051, 0.4002018785406001, 0.47577646193668305, 0.46947389131125355, 0.39451447317383304, 0.5023282958115685, 0.541788821424157, 0.32919645985040796, 0.5074812556200582, 0.4285261450712013, 0.4845558266185712, 0.5304171153629543, 0.5092032503660203, 0.4753478837434322, 0.448153218512298, 0.47867039484465956, 0.4852752243854846, 0.501362170533094, 0.42829810986643513, 0.44078385567455275, 0.4018099136772415, 0.4495881969010463, 0.569451890872498, 0.4758832263044546, 0.36919850168726437, 0.191651149880181, 0.43438880199332874, 0.5401431997328361, 0.46985917264683547, 0.5168924027394912, 0.3853153124297045, 0.19838357521998465, 0.3968481116301608, 0.5709191314784772, 0.4558451292974615, 0.5989934895692369, 0.2983787118829033, 0.4127 ...

# %%
# print the details of the 2 special portfolios
print(f"{min_variance_port.T.apply(lambda x: x*100)}")
print(f"{sharpe_portfolio.T.apply(lambda x: x*100)}")
# Out:
#                      40
# Returns        4.819952
# Volatility    13.856047
# Sharpe Ratio  34.785911
# CNP Weight    21.158978
# F Weight       9.370845
# WMT Weight    29.475966
# GE Weight      0.830915
# TSLA Weight   39.163296
#                    2627
# Returns       11.745428
# Volatility    17.808260
# Sharpe Ratio  65.954946
# CNP Weight    37.145046
# F Weight       1.116228
# WMT Weight    37.595804
# GE Weight     23.213478
# TSLA Weight    0.929444

# %% [markdown]
# Documentation:
#
# [Markowitz’s Efficient Frontier in Python [Part 1/2]](https://medium.com/python-data/effient-frontier-in-python-34b0c3043314)
#
# [Efficient Frontier & Portfolio Optimization with Python [Part 2/2]](https://medium.com/python-data/efficient-frontier-portfolio-optimization-with-python-part-2-2-2fe23413ad94)
